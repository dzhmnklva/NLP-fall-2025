# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import re

from tensorflow.keras.layers import Dense, GRU, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('drive/MyDrive/Aruzhan/train_data_true.txt', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('drive/MyDrive/Aruzhan/train_data_false.txt', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(GRU(128, return_sequences=True))
model.add(GRU(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

# t = "Это шедевр изобразительного".lower()
t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()
data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 48 45 93
# [('ты', 50), ('сильнее', 5), ('чем', 10), ('кажешься', 1), ('умнее', 1), ('думаешь', 1), ('и', 76), ('всегда', 4), ('способен', 5), ('подняться', 1)]
# Ты сильнее, чем кажешься, умнее, чем думаешь, и всегда способен подняться выше, если выбираешь верит
# [[227 228  30  38  80   5  31   1 126 127]
#  [ 14 232 233  66 129   3   8   4 234  81]
#  [ 85  86   1 235  41 133 236 134   3 135]
#  [ 67  23 241 242 243  54 244  43   5 245]
#  [247 248  87 249 250 251   1  88 136  89]
#  [138  68 254 139   1  90  25  66 140 141]
#  [ 69  33   8 257 258 259  70  14  41 142]
#  [143 264   1 144 265 266 145 146  11 147]
#  [  6  25 268 269  71  45 149 270 271 272]
#  [273 274   1  89  56 151 275   1 276 277]
#  [ 94  10   3 152  46   8  30  34  35 280]
#  [ 54 283  34   5  70  14 284  95   1 285]
#  [142  67  23 154 155   1 289 290  69  33]
#  [ 47  82  43  36  10   3 128  22 157 293]
#  [  3 296  34  57 158 297  89   1 298 299]
#  [301  19 302  27 303  97 304  84   1 159]
#  [  3  65 305  55   1   3  28  19 161 306]
#  [309  32  11  86  85   1 310   5 311 312]
#  [318  28  32  11  98 319  19  59 164 320]
#  [  2 323   4 100   6 324 101   3 325 326]
#  [329 159 330   6 127 331 166 102 332 333]
#  [168 169  46  60 336 103 104   2 337  81]
#  [ 92 170  57 341 342   2 343   5  70  14]
#  [173   1 105   4 174 345  11 175 106 346]
#  [  2  12 637 638  63 639  54 222  39 640]
#  [  2 643 644   4 645   1 646 647 648  25]
#  [649   6  14  17 650   1   3 211 651 214]
#  [193 218  62   2 108   4 653 654 655  50]
#  [ 21 658  64 659 102 114 660   1   4 661]
#  [ 33  59 203 118 664 665  19   2  62 210]
#  [  3 668  75 669 670  19 199   1   4 671]
#  [ 10  43 221 674 675 676 677   1 678 209]
#  [ 57 129 123 216   1  48 679 680 116 681]
#  [683   1 125 684 685 686  51 687 106 688]
#  [690  21  63 691  54 222 692 213   1 693]]
# [('и', 1), ('что', 2), ('ты', 3), ('не', 4), ('в', 5), ('а', 6), ('кажется', 7), ('даже', 8), ('иногда', 9), ('когда', 10), ('тебя', 11), ('каждый', 12), ('бывает', 13), ('жизнь', 14), ('порой', 15), ('потому', 16), ('слишком', 17), ('чем', 18), ('на', 19), ('всё', 20), ('будто', 21), ('себе', 22), ('только', 23), ('с', 24), ('мысли', 25), ('пусть', 26), ('вокруг', 27), ('уже', 28), ('кажутся', 29), ('если', 30), ('себя', 31), ('делает', 32), ('вперед', 33), ('путь', 34), ('становится', 35), ('больше', 36), ('ни', 37), ('выбираешь', 38), ('новый', 39), ('день', 40), ('к', 41), ('твоя', 42), ('тебе', 43), ('можешь', 44), ('любые', 45), ('идти', 46), ('мир', 47), ('это', 48), ('твои', 49), ('внутри', 50), ('ощущение', 51), ('сильнее', 52), ('способен', 53), ('обязательно', 54), ('быть', 55), ('просто', 56), ('для', 57), ('тем', 58), ('по', 59), ('дальше', 60), ('приносит', 61), ('то', 62), ('за', 63), ('из', 64), ('всегда', 65), ('о', 66), ('стоит', 67), ('спокойствие', 68), ('шаг', 69), ('твою', 70), ('чтобы', 71), ('лучшее', 72), ('которая', 73), ('будут', 74), ('двигаться', 75), ('будущее', 76), ('ошибки', 77), ('невозможно', 78), ('много', 79), ('верить', 80), ('раньше', 81), ('дает', 82), ('стать', 83), ('лучше', 84), ('спокойнее', 85), ('мудрее', 86), ('моменты', 87), ('становятся', 88), ('вдохновения', 89), ('добрые', 90), ('маленькая', 91), ('сердце', 92), ('сила', 93), ('тогда', 94), ('уверенно', 95), ('шанс', 96), ('их', 97), ('человеком', 98), ('момент', 99), ('прошлое', 100), ('который', 101), ('где', 102), ('от', 103), ('того', 104), ('никто', 105), ('внутреннего', 106), ('как', 107), ('сам', 108), ('твой', 109), ('изменения', 110), ('так', 111), ('мечты', 112), ('продолжать', 113), ('все', 114), ('уходит', 115), ('чувство', 116), ('усталости', 117), ('без', 118), ('люди', 119), ('сложно', 120), ('или', 121), ('почти', 122), ('нет', 123), ('тяжело', 124), ('давит', 125), ('свои', 126), ('возможности', 127), ('позволяешь', 128), ('которых', 129), ('возможность', 130), ('начать', 131), ('заново', 132), ('тому', 133), ('которое', 134), ('хочешь', 135), ('источником', 136), ('справиться', 137), ('сохраняешь', 138), ('уверенность', 139), ('своих', 140), ('силах', 141), ('лучшему', 142), ('уважения', 143), ('всех', 144), ('которые', 145), ('ждут', 146), ('впереди', 147), ('твое', 148), ('трудности', 149), ('создавать', 150), ('оставаясь', 151), ('продолжаешь', 152), ('изменить', 153), ('заметить', 154), ('его', 155), ('заслуживаешь', 156), ('принимать', 157), ('новых', 158), ('светлее', 159), ('которым', 160), ('правильном', 161), ('растешь', 162), ('каждое', 163), ('настоящему', 164), ('свою', 165), ('там', 166), ('у', 167), ('есть', 168), ('силы', 169), ('открытым', 170), ('достоин', 171), ('уверенным', 172), ('спокойным', 173), ('может', 174), ('этого', 175), ('радости', 176), ('красоту', 177), ('света', 178), ('становишься', 179), ('постепенно', 180), ('уверенностью', 181), ('которого', 182), ('урок', 183), ('уверенными', 184), ('многого', 185), ('менять', 186), ('спокойствием', 187), ('радость', 188), ('тоже', 189), ('эта', 190), ('каждым', 191), ('создать', 192), ('трудно', 193), ('раз', 194), ('шаги', 195), ('новая', 196), ('слово', 197), ('превращается', 198), ('месте', 199), ('усилия', 200), ('пустоту', 201), ('требует', 202), ('инерции', 203), ('таким', 204), ('сил', 205), ('тяжёлыми', 206), ('прошло', 207), ('ничего', 208), ('спокойно', 209), ('новое', 210), ('постоянно', 211), ('маленькие', 212), ('тень', 213), ('позади', 214), ('вопросов', 215), ('ответов', 216), ('же', 217), ('объяснить', 218), ('глубоко', 219), ('хорошие', 220), ('хочется', 221), ('придёт', 222), ('разговоры', 223), ('кажешься', 224), ('умнее', 225), ('думаешь', 226), ('подняться', 227), ('выше', 228), ('мечтать', 229), ('смело', 230), ('широко', 231), ('открывает', 232), ('двери', 233), ('подозревал', 234), ('приблизиться', 235), ('будущему', 236), ('энергия', 237), ('привлекает', 238), ('удивительные', 239), ('события', 240), ('улыбнуться ...
# (93, 10) (93, 2)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6014 - loss: 0.6916
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6131 - loss: 0.6910
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6707 - loss: 0.6890
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7484 - loss: 0.6876
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7328 - loss: 0.6860
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7709 - loss: 0.6842
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7802 - loss: 0.6822
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7606 - loss: 0.6813
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7973 - loss: 0.6785
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7626 - loss: 0.6776
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8139 - loss: 0.6741
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8583 - loss: 0.6706
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8520 - loss: 0.6671
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8285 - loss: 0.6643
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8969 - loss: 0.6584
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9350 - loss: 0.6509
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9380 - loss: 0.6474
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9629 - loss: 0.6373
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9736 - loss: 0.6288
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9736 - loss: 0.6211
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9736 - loss: 0.6080
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9907 - loss: 0.5956
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9829 - loss: 0.5777
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9907 - loss: 0.5660
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9946 - loss: 0.5399
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9907 - loss: 0.5092
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - loss: 0.4879
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9829 - loss: 0.4491
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.4132
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.3755
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.3285
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.2795
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.2362
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1963
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1531
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.1165
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0878
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0677
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0503
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0301
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0177
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0056
# ['не', 'за', 'это', 'же']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# [[0.2042063 0.7957937]]
# 1
